# %% [markdown]
# # Introduction
#
# In this notebook, I will be recreating a kernel, [located here](https://www.kaggle.com/warsfor42/python-data-visualizations) in order to further my understanding of the [Iris species data set](https://www.kaggle.com/uciml/iris/).
#
# ## Libraries
#
# For this notebook, we will be utilizing several Python libraries:
# 1. Pandas
# 2. Seaborn
# 3. Matplotlib

# %%
#import libraries
import pandas
import numpy
import pygal
import seaborn as sns

# %%
#read in IRIS data file
iris = pandas.read_csv('iris.csv')

# %%
#some commands to get familiar with the dataset
iris.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
iris.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
species_count = pandas.value_counts(iris["Species"])
species_count
# Out:
# Iris-virginica     50
# Iris-setosa        50
# Iris-versicolor    50
# Name: Species, dtype: int64

# %%
# %matplotlib inline
from IPython.display import SVG, HTML

html_pygal = """
<!DOCTYPE html>
<html>
  <head>
  <script type="text/javascript" src="http://kozea.github.com/pygal.js/javascripts/svg.jquery.js"></script>
  <script type="text/javascript" src="http://kozea.github.com/pygal.js/javascripts/pygal-tooltips.js"></script>
    <!-- ... -->
  </head>
  <body>
    <figure>
      {pygal_render}
    </figure>
  </body>
</html>
"""

# %%
# show a bar chart of all the sepal lengths
bar_sepal = pygal.Bar()
bar_sepal.title = "Sepal Lengths"
bar_sepal.add("Septal Length", iris["SepalLengthCm"])
HTML(html_pygal.format(pygal_render=bar_sepal.render()))
# Out:
# <!DOCTYPE html>
# <html>
#   <head>
#   <script type="text/javascript" src="http://kozea.github.com/pygal.js/javascripts/svg.jquery.js"></script>
#   <script type="text/javascript" src="http://kozea.github.com/pygal.js/javascripts/pygal-tooltips.js"></script>
#     <!-- ... -->
#   </head>
#   <body>
#     <figure>
#       b'<?xml version=\'1.0\' encoding=\'utf-8\'?>\n<svg xmlns:xlink="http://www.w3.org/1999/xlink" xmlns="http://www.w3.org/2000/svg" id="chart-c8e38044-9bf3-45ac-ad59-0a23155c9603" class="pygal-chart" viewBox="0 0 800 600"><!--Generated with pygal 2.4.0 (lxml) \xc2\xa9Kozea 2012-2016 on 2017-09-27--><!--http://pygal.org--><!--http://github.com/Kozea/pygal--><defs><style type="text/css">#chart-c8e38044-9bf3-45ac-ad59-0a23155c9603{-webkit-user-select:none;-webkit-font-smoothing:antialiased;font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace}#chart-c8e38044-9bf3-45ac-ad59-0a23155c9603 .title{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:16px}#chart-c8e38044-9bf3-45ac-ad59-0a23155c9603 .legends .legend text{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:14px}#chart-c8e38044-9bf3-45ac-ad59-0a23155c9603 .axis text{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-c8e38044-9bf3-45ac-ad59-0a23155c9603 .axis text.major{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-c8e38044-9bf3-45ac-ad59-0a23155c9603 .text-overlay text.value{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:16px}#chart-c8e38044-9bf3-45ac-ad59-0a23155c9603 .text-overlay text.label{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-c8e38044-9bf3-45ac-ad59-0a23155c9603 .tooltip{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:14px}#chart-c8e38044-9bf3-45ac-ad59-0a23155c9603 text.no_data{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:64px}\n#chart-c8e38044-9bf3-45ac-ad59-0a23155c9603{background-color:rgba(249,249,249,1)}#chart-c8e38044-9bf3-45ac-ad59-0a23155c9603 path,#chart-c8e38044-9bf3-45ac-ad59-0a23155c9603 line,#chart-c8e38044-9bf3-45ac-ad59-0a23155c9603 rect,#chart-c8e38044-9bf3-45ac-ad59-0a23155c9603 circle{-webkit-transition:150ms;-moz-transition:150ms;transition:150ms}#chart-c8e38044-9bf3-45ac-ad59-0a23155c9603 .graph &gt; .background{fill:rgba(249,249,249,1)}#chart-c8e38044-9bf3-45ac-ad59-0a23155c9603 .plot &gt; .background{fill:rgba(255,255,255,1)}#chart-c8e38044-9bf3-45ac-ad59-0a23155c9603 .graph{fill:rgba(0,0,0,.87)}#chart-c8e38044-9bf3-45ac-ad59-0a23155c9603 text.no_data{fill:rgba(0,0,0,1)}#chart-c8e38044-9bf3-45ac-ad59-0a23155c9603 .title{fill:rgba(0,0,0,1)}#chart-c8e38044-9bf3-45ac-ad59-0a23155c9603 .legends .legend text{fill:rgba(0,0,0,.87)}#chart-c8e38044-9bf3-45ac-ad59-0a23155c9603 .legends .legend:hover text{fill:rgba(0,0,0,1)}#chart-c8e38044-9bf3-45ac-ad59-0a23155c9603 .axis .line{stroke:rgba(0,0,0,1)}#chart-c8e38044-9bf3-45ac-ad59-0a23155c9603 .axis .guide.line{stroke:rgba(0,0,0,.54)}#chart-c8e38044-9bf3-45ac-ad59-0a23155c9603 .axis .major.line{stroke:rgba(0,0,0,.87)}#chart-c8e38044-9bf3-45ac-ad59-0a23155c9603 .axis text.major{fill:rgba(0,0,0,1)}#chart-c8e38044-9bf3-45ac-ad59-0a23155c9603 .axis.y .guides:hover .guide.line,#chart-c8e38044-9bf3-45ac-ad59-0a23155c9603 .line-graph .axis.x .guides:hover .guide.line,#chart-c8e38044-9bf3-45ac-ad59-0a23155c9603 .stackedline-graph .axis.x .guides:hover .guide.line,#chart-c8e38044-9bf3-45ac-ad59-0a23155c9603 .xy-graph .axis.x .guides:hover .guide.line{stroke:rgba(0,0,0,1)}#chart-c8e38044-9bf3-45ac-ad59-0a23155c9603 .axis .guides:hover text{fill:rgba(0,0,0,1)}#chart-c8e38044-9bf3-45ac-ad59-0a23155c9603 .reactive{fill-opacity:.7;stroke-opacity:.8}#chart-c8e38044-9bf3-45ac-ad59-0a23155c9603 .ci{stroke:rgba(0,0,0,.87)}#chart-c8e38044-9bf3-45ac-ad59-0a23155c9603 .reactive.active,#chart-c8e38044-9bf3-45ac-ad59-0a23155c9603 .active .reactive{fill-opacity:.8;stroke-opacity:.9;stroke-width:4}#chart-c8e38044-9bf3-45ac-ad59-0a23155c9603 .ci .reactive.active{stroke-width:1.5}#chart-c8e38044-9bf3-45ac-ad59-0a23155c9603 .series text{fill:rgba(0,0,0,1)}#chart-c8e38044-9bf3-45ac-ad59-0a23155c9603 .tooltip rect{fill:rgba(255,255,255,1);stroke:rgba(0,0,0,1);-webkit-transition:opacity 15 ...

# %%
# Let's compare sepal lengths and widths in a line chart
line_compare = pygal.StackedLine(fille = True)
line_compare.title = "Sepal Lengths and Widths"
line_compare.add("Sepal Length", iris["SepalLengthCm"][0:10])
line_compare.add("Sepal Width", iris["SepalWidthCm"][0:10])
HTML(html_pygal.format(pygal_render=line_compare.render()))
# Out:
# <!DOCTYPE html>
# <html>
#   <head>
#   <script type="text/javascript" src="http://kozea.github.com/pygal.js/javascripts/svg.jquery.js"></script>
#   <script type="text/javascript" src="http://kozea.github.com/pygal.js/javascripts/pygal-tooltips.js"></script>
#     <!-- ... -->
#   </head>
#   <body>
#     <figure>
#       b'<?xml version=\'1.0\' encoding=\'utf-8\'?>\n<svg xmlns:xlink="http://www.w3.org/1999/xlink" xmlns="http://www.w3.org/2000/svg" id="chart-4aa32604-6999-4528-b97e-290a2576f9b1" class="pygal-chart" viewBox="0 0 800 600"><!--Generated with pygal 2.4.0 (lxml) \xc2\xa9Kozea 2012-2016 on 2017-09-27--><!--http://pygal.org--><!--http://github.com/Kozea/pygal--><defs><style type="text/css">#chart-4aa32604-6999-4528-b97e-290a2576f9b1{-webkit-user-select:none;-webkit-font-smoothing:antialiased;font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace}#chart-4aa32604-6999-4528-b97e-290a2576f9b1 .title{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:16px}#chart-4aa32604-6999-4528-b97e-290a2576f9b1 .legends .legend text{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:14px}#chart-4aa32604-6999-4528-b97e-290a2576f9b1 .axis text{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-4aa32604-6999-4528-b97e-290a2576f9b1 .axis text.major{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-4aa32604-6999-4528-b97e-290a2576f9b1 .text-overlay text.value{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:16px}#chart-4aa32604-6999-4528-b97e-290a2576f9b1 .text-overlay text.label{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-4aa32604-6999-4528-b97e-290a2576f9b1 .tooltip{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:14px}#chart-4aa32604-6999-4528-b97e-290a2576f9b1 text.no_data{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:64px}\n#chart-4aa32604-6999-4528-b97e-290a2576f9b1{background-color:rgba(249,249,249,1)}#chart-4aa32604-6999-4528-b97e-290a2576f9b1 path,#chart-4aa32604-6999-4528-b97e-290a2576f9b1 line,#chart-4aa32604-6999-4528-b97e-290a2576f9b1 rect,#chart-4aa32604-6999-4528-b97e-290a2576f9b1 circle{-webkit-transition:150ms;-moz-transition:150ms;transition:150ms}#chart-4aa32604-6999-4528-b97e-290a2576f9b1 .graph &gt; .background{fill:rgba(249,249,249,1)}#chart-4aa32604-6999-4528-b97e-290a2576f9b1 .plot &gt; .background{fill:rgba(255,255,255,1)}#chart-4aa32604-6999-4528-b97e-290a2576f9b1 .graph{fill:rgba(0,0,0,.87)}#chart-4aa32604-6999-4528-b97e-290a2576f9b1 text.no_data{fill:rgba(0,0,0,1)}#chart-4aa32604-6999-4528-b97e-290a2576f9b1 .title{fill:rgba(0,0,0,1)}#chart-4aa32604-6999-4528-b97e-290a2576f9b1 .legends .legend text{fill:rgba(0,0,0,.87)}#chart-4aa32604-6999-4528-b97e-290a2576f9b1 .legends .legend:hover text{fill:rgba(0,0,0,1)}#chart-4aa32604-6999-4528-b97e-290a2576f9b1 .axis .line{stroke:rgba(0,0,0,1)}#chart-4aa32604-6999-4528-b97e-290a2576f9b1 .axis .guide.line{stroke:rgba(0,0,0,.54)}#chart-4aa32604-6999-4528-b97e-290a2576f9b1 .axis .major.line{stroke:rgba(0,0,0,.87)}#chart-4aa32604-6999-4528-b97e-290a2576f9b1 .axis text.major{fill:rgba(0,0,0,1)}#chart-4aa32604-6999-4528-b97e-290a2576f9b1 .axis.y .guides:hover .guide.line,#chart-4aa32604-6999-4528-b97e-290a2576f9b1 .line-graph .axis.x .guides:hover .guide.line,#chart-4aa32604-6999-4528-b97e-290a2576f9b1 .stackedline-graph .axis.x .guides:hover .guide.line,#chart-4aa32604-6999-4528-b97e-290a2576f9b1 .xy-graph .axis.x .guides:hover .guide.line{stroke:rgba(0,0,0,1)}#chart-4aa32604-6999-4528-b97e-290a2576f9b1 .axis .guides:hover text{fill:rgba(0,0,0,1)}#chart-4aa32604-6999-4528-b97e-290a2576f9b1 .reactive{fill-opacity:.7;stroke-opacity:.8}#chart-4aa32604-6999-4528-b97e-290a2576f9b1 .ci{stroke:rgba(0,0,0,.87)}#chart-4aa32604-6999-4528-b97e-290a2576f9b1 .reactive.active,#chart-4aa32604-6999-4528-b97e-290a2576f9b1 .active .reactive{fill-opacity:.8;stroke-opacity:.9;stroke-width:4}#chart-4aa32604-6999-4528-b97e-290a2576f9b1 .ci .reactive.active{stroke-width:1.5}#chart-4aa32604-6999-4528-b97e-290a2576f9b1 .series text{fill:rgba(0,0,0,1)}#chart-4aa32604-6999-4528-b97e-290a2576f9b1 .tooltip rect{fill:rgba(255,255,255,1);stroke:rgba(0,0,0,1);-webkit-transition:opacity 15 ...

# %%
#i love donut charts so here is one for good measure
pie_chart = pygal.Pie(inner_radius=.5)
pie_chart.title = 'Total area by species'
pie_chart.add('Sepal Area', (iris["SepalLengthCm"]*iris["SepalWidthCm"]).sum())
pie_chart.add('Petal Area', (iris["PetalLengthCm"]*iris["PetalWidthCm"]).sum())
HTML(html_pygal.format(pygal_render=pie_chart.render()))
# Out:
# <!DOCTYPE html>
# <html>
#   <head>
#   <script type="text/javascript" src="http://kozea.github.com/pygal.js/javascripts/svg.jquery.js"></script>
#   <script type="text/javascript" src="http://kozea.github.com/pygal.js/javascripts/pygal-tooltips.js"></script>
#     <!-- ... -->
#   </head>
#   <body>
#     <figure>
#       b'<?xml version=\'1.0\' encoding=\'utf-8\'?>\n<svg xmlns:xlink="http://www.w3.org/1999/xlink" xmlns="http://www.w3.org/2000/svg" id="chart-ab169884-2a80-4291-85a9-63a448bfe29b" class="pygal-chart" viewBox="0 0 800 600"><!--Generated with pygal 2.4.0 (lxml) \xc2\xa9Kozea 2012-2016 on 2017-09-27--><!--http://pygal.org--><!--http://github.com/Kozea/pygal--><defs><style type="text/css">#chart-ab169884-2a80-4291-85a9-63a448bfe29b{-webkit-user-select:none;-webkit-font-smoothing:antialiased;font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace}#chart-ab169884-2a80-4291-85a9-63a448bfe29b .title{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:16px}#chart-ab169884-2a80-4291-85a9-63a448bfe29b .legends .legend text{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:14px}#chart-ab169884-2a80-4291-85a9-63a448bfe29b .axis text{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-ab169884-2a80-4291-85a9-63a448bfe29b .axis text.major{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-ab169884-2a80-4291-85a9-63a448bfe29b .text-overlay text.value{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:16px}#chart-ab169884-2a80-4291-85a9-63a448bfe29b .text-overlay text.label{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-ab169884-2a80-4291-85a9-63a448bfe29b .tooltip{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:14px}#chart-ab169884-2a80-4291-85a9-63a448bfe29b text.no_data{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:64px}\n#chart-ab169884-2a80-4291-85a9-63a448bfe29b{background-color:rgba(249,249,249,1)}#chart-ab169884-2a80-4291-85a9-63a448bfe29b path,#chart-ab169884-2a80-4291-85a9-63a448bfe29b line,#chart-ab169884-2a80-4291-85a9-63a448bfe29b rect,#chart-ab169884-2a80-4291-85a9-63a448bfe29b circle{-webkit-transition:150ms;-moz-transition:150ms;transition:150ms}#chart-ab169884-2a80-4291-85a9-63a448bfe29b .graph &gt; .background{fill:rgba(249,249,249,1)}#chart-ab169884-2a80-4291-85a9-63a448bfe29b .plot &gt; .background{fill:rgba(255,255,255,1)}#chart-ab169884-2a80-4291-85a9-63a448bfe29b .graph{fill:rgba(0,0,0,.87)}#chart-ab169884-2a80-4291-85a9-63a448bfe29b text.no_data{fill:rgba(0,0,0,1)}#chart-ab169884-2a80-4291-85a9-63a448bfe29b .title{fill:rgba(0,0,0,1)}#chart-ab169884-2a80-4291-85a9-63a448bfe29b .legends .legend text{fill:rgba(0,0,0,.87)}#chart-ab169884-2a80-4291-85a9-63a448bfe29b .legends .legend:hover text{fill:rgba(0,0,0,1)}#chart-ab169884-2a80-4291-85a9-63a448bfe29b .axis .line{stroke:rgba(0,0,0,1)}#chart-ab169884-2a80-4291-85a9-63a448bfe29b .axis .guide.line{stroke:rgba(0,0,0,.54)}#chart-ab169884-2a80-4291-85a9-63a448bfe29b .axis .major.line{stroke:rgba(0,0,0,.87)}#chart-ab169884-2a80-4291-85a9-63a448bfe29b .axis text.major{fill:rgba(0,0,0,1)}#chart-ab169884-2a80-4291-85a9-63a448bfe29b .axis.y .guides:hover .guide.line,#chart-ab169884-2a80-4291-85a9-63a448bfe29b .line-graph .axis.x .guides:hover .guide.line,#chart-ab169884-2a80-4291-85a9-63a448bfe29b .stackedline-graph .axis.x .guides:hover .guide.line,#chart-ab169884-2a80-4291-85a9-63a448bfe29b .xy-graph .axis.x .guides:hover .guide.line{stroke:rgba(0,0,0,1)}#chart-ab169884-2a80-4291-85a9-63a448bfe29b .axis .guides:hover text{fill:rgba(0,0,0,1)}#chart-ab169884-2a80-4291-85a9-63a448bfe29b .reactive{fill-opacity:.7;stroke-opacity:.8}#chart-ab169884-2a80-4291-85a9-63a448bfe29b .ci{stroke:rgba(0,0,0,.87)}#chart-ab169884-2a80-4291-85a9-63a448bfe29b .reactive.active,#chart-ab169884-2a80-4291-85a9-63a448bfe29b .active .reactive{fill-opacity:.8;stroke-opacity:.9;stroke-width:4}#chart-ab169884-2a80-4291-85a9-63a448bfe29b .ci .reactive.active{stroke-width:1.5}#chart-ab169884-2a80-4291-85a9-63a448bfe29b .series text{fill:rgba(0,0,0,1)}#chart-ab169884-2a80-4291-85a9-63a448bfe29b .tooltip rect{fill:rgba(255,255,255,1);stroke:rgba(0,0,0,1);-webkit-transition:opacity 15 ...

# %%
#switch to matplotlib for different types of charts
iris.plot(kind="scatter", x="SepalLengthCm", y="SepalWidthCm")

# %%
#default colors are teh same, so let's make it even harder by adding in some clashing colors
color_key = {'Iris-setosa':'pink', 'Iris-virginica':'green', 'Iris-versicolor':'yellow'}

iris.plot(kind="scatter", x="SepalLengthCm", y="SepalWidthCm", c = [color_key[i] for i in iris["Species"]])

# %%
#Now to recreate some of the charts and information from this kernel: https://www.kaggle.com/ash316/ml-from-scratch-with-iris

import matplotlib.pyplot as plt

#Comparing Petal Lngth and Width

plot = iris[iris.Species == 'Iris-setosa'].plot.scatter(x='PetalLengthCm', y='PetalWidthCm', color='green', label='Setosa')
iris[iris.Species == 'Iris-versicolor'].plot.scatter(x='PetalLengthCm', y='PetalWidthCm', color='yellow', label='versicolor', ax=plot)
iris[iris.Species == 'Iris-virginica'].plot.scatter(x='PetalLengthCm', y='PetalWidthCm', color='red', label='virginica', ax=plot)

plot.set_xlabel("Petal Length")
plot.set_ylabel("Petal Width")
plot.set_title("Petal Length vs Width")
plot = plt.gcf()
plt.show()

# %%
#In this kernel, I was just introduced to a new visualization called a violinplot.  It appears this helps visualize the disparity in the values within a series

plt.figure(figsize=(15,10))
plt.subplot(2,2,1)  #TODO: figure out what this does
sns.violinplot(x="Species",y="PetalLengthCm",data=iris)
